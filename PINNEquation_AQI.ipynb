# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashaswini-Sridhar/Physic-Induced-NN/blob/main/PINNEquation_AQI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Pollutant importance percentages for Bengaluru
pollutant_importance = {
    'PM2.5': 0.65,  # 65% (midpoint of 60-70%)
    'PM10': 0.20,   # 20% (midpoint of 15-25%)
    'NO2': 0.075,   # 7.5% (midpoint of 5-10%)
    'O3': 0.075,    # 7.5% (midpoint of 5-10%)
    'CO': 0.015,    # 1.5% (<2%)
    'SO2': 0.005,   # 0.5% (<1%)
    'NH3': 0.005    # 0.5% (<1%)
}

class PINN_AQI_Model(keras.Model):
    def __init__(self, hidden_layers=[64, 32, 16], **kwargs):
        super().__init__(**kwargs)

        # Define the neural network architecture
        self.input_layer = keras.layers.Dense(hidden_layers[0], activation='tanh')
        self.hidden_layers = []
        for units in hidden_layers[1:]:
            self.hidden_layers.append(keras.layers.Dense(units, activation='tanh'))
        self.output_layer = keras.layers.Dense(1)

        # Physics parameters
        self.diffusion_coef = tf.Variable(0.1, dtype=tf.float32, name='diffusion_coef')
        self.reaction_rates = {
            'k1': tf.Variable(0.01, dtype=tf.float32, name='k1'),
            'k2': tf.Variable(0.005, dtype=tf.float32, name='k2'),
            'k3': tf.Variable(0.02, dtype=tf.float32, name='k3')
        }

    def call(self, inputs):
        # Unpack inputs
        T, P, H, SO2, NO2, CO, CO2, PM25, PM10, H2O, VOC, VOS = [
            inputs[:, i:i+1] for i in range(12)
        ]

        # Neural network part
        x = self.input_layer(inputs)
        for layer in self.hidden_layers:
            x = layer(x)
        nn_output = self.output_layer(x)

        # Physical model part
        # Temperature influence function (simplified Arrhenius equation)
        f_T = tf.exp(-0.1 / (0.008314 * (T + 273.15)))

        # Pressure influence function
        f_P = tf.pow(P / 1013.25, 0.2)

        # Humidity influence function
        f_H = 1.0 + 0.01 * H

        # Reaction terms
        R_term = (
            self.reaction_rates['k1'] * NO2 * VOC * f_T +
            self.reaction_rates['k2'] * SO2 * H2O * f_P +
            self.reaction_rates['k3'] * PM25 * f_H
        )

        # Climate correction factor
        kappa = 0.8 * tf.pow(T / 25.0, 0.1) * tf.pow(P / 1013.25, 0.05) * tf.pow(H / 60.0, 0.2)

        # Combine NN output with physical model
        # Scale each pollutant by importance percentage
        weighted_pollutants = (
            pollutant_importance['PM2.5'] * PM25 +
            pollutant_importance['PM10'] * PM10 +
            pollutant_importance['NO2'] * NO2 +
            pollutant_importance['O3'] * VOC + # Using VOC as proxy for O3
            pollutant_importance['CO'] * CO +
            pollutant_importance['SO2'] * SO2 +
            pollutant_importance['NH3'] * VOS  # Using VOS as proxy for NH3
        )

        # Final AQI calculation combining NN and physics
        aqi = nn_output + weighted_pollutants + R_term - kappa

        return aqi

    def physics_loss(self, inputs, time_delta=0.1, space_delta=0.1):
        """
        Compute the physics-informed loss component
        """
        with tf.GradientTape() as tape:
            tape.watch(inputs)
            aqi = self(inputs)

        # First derivatives
        grad_aqi = tape.gradient(aqi, inputs)

        # Extract time derivative (assuming first input is time)
        daqi_dt = grad_aqi[:, 0:1]

        # Compute diffusion term (Laplacian approximation)
        # This is simplified; a real implementation would compute proper spatial derivatives
        diffusion_term = self.diffusion_coef * tf.reduce_mean(grad_aqi[:, 1:4], axis=1, keepdims=True)

        # Unpack inputs for reaction terms
        T, P, H, SO2, NO2, CO, CO2, PM25, PM10, H2O, VOC, VOS = [
            inputs[:, i:i+1] for i in range(12)
        ]

        # Temperature influence function
        f_T = tf.exp(-0.1 / (0.008314 * (T + 273.15)))

        # Pressure influence function
        f_P = tf.pow(P / 1013.25, 0.2)

        # Humidity influence function
        f_H = 1.0 + 0.01 * H

        # Reaction terms
        R_term = (
            self.reaction_rates['k1'] * NO2 * VOC * f_T +
            self.reaction_rates['k2'] * SO2 * H2O * f_P +
            self.reaction_rates['k3'] * PM25 * f_H
        )

        # Climate correction factor
        kappa = 0.8 * tf.pow(T / 25.0, 0.1) * tf.pow(P / 1013.25, 0.05) * tf.pow(H / 60.0, 0.2)

        # PDE residual
        pde_residual = daqi_dt - diffusion_term + R_term - kappa

        return tf.reduce_mean(tf.square(pde_residual))

    def train_step(self, data):
        # Unpack data
        inputs, targets = data

        with tf.GradientTape() as tape:
            # Forward pass
            predictions = self(inputs)

            # Compute data loss
            data_loss = tf.reduce_mean(tf.square(predictions - targets))

            # Compute physics loss
            phys_loss = self.physics_loss(inputs)

            # Total loss (lambda = 0.1 balances data and physics losses)
            total_loss = data_loss + 0.1 * phys_loss

        # Compute gradients
        gradients = tape.gradient(total_loss, self.trainable_variables)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

        # Return metrics
        return {
            "loss": total_loss,
            "data_loss": data_loss,
            "physics_loss": phys_loss
        }

# Example usage
def create_and_train_model(train_data, train_targets, epochs=100):
    model = PINN_AQI_Model()
    model.compile(optimizer='adam')

    model.fit(train_data, train_targets, epochs=epochs)
    return model

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# ... (Your PINN_AQI_Model class definition here) ...

# 1. Create an instance of the model:
model = PINN_AQI_Model()

# 2. Compile the model:
model.compile(optimizer='adam')  # You can choose a different optimizer if needed

# 3. Generate or load your input data:
# Replace this with your actual data loading/generation logic
num_samples = 1000
input_data = np.random.rand(num_samples, 12)  # 12 input features
target_data = np.random.rand(num_samples, 1)  # 1 output (AQI)


# 4. Train the model:
model.fit(input_data, target_data, epochs=100)  # Adjust epochs as needed

# 5. Make predictions:
# Replace this with your actual prediction data
prediction_data = np.random.rand(10, 12)  # 10 samples for prediction
predictions = model.predict(prediction_data)

# To see the output, run the code.
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - data_loss: 0.1107 - loss: 0.2900 - physics_loss: 1.7933
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0877 - loss: 0.2636 - physics_loss: 1.7585
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0915 - loss: 0.2676 - physics_loss: 1.7601
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0913 - loss: 0.2668 - physics_loss: 1.7549
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0873 - loss: 0.2633 - physics_loss: 1.7602
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0868 - loss: 0.2615 - physics_loss: 1.7474
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0854 - loss: 0.2605 - physics_loss: 1.7511
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0835 - loss: 0.2578 - physics_loss: 1.7426
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0878 - loss: 0.2614 - physics_loss: 1.7366
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0864 - loss: 0.2601 - physics_loss: 1.7373
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0840 - loss: 0.2565 - physics_loss: 1.7251
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0858 - loss: 0.2574 - physics_loss: 1.7157
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0837 - loss: 0.2553 - physics_loss: 1.7158
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0846 - loss: 0.2552 - physics_loss: 1.7061
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0830 - loss: 0.2518 - physics_loss: 1.6876
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0860 - loss: 0.2554 - physics_loss: 1.6933
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0808 - loss: 0.2485 - physics_loss: 1.6767
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0832 - loss: 0.2492 - physics_loss: 1.6596
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0854 - loss: 0.2491 - physics_loss: 1.6369
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0859 - loss: 0.2474 - physics_loss: 1.6152
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0858 - loss: 0.2453 - physics_loss: 1.5946
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0817 - loss: 0.2380 - physics_loss: 1.5631
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0851 - loss: 0.2387 - physics_loss: 1.5358
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0845 - loss: 0.2432 - physics_loss: 1.5871
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0821 - loss: 0.2397 - physics_loss: 1.5758
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0852 - loss: 0.2342 - physics_loss: 1.4906
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0825 - loss: 0.2517 - physics_loss: 1.6919
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0835 - loss: 0.2260 - physics_loss: 1.4253
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0859 - loss: 0.2362 - physics_loss: 1.5023
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0833 - loss: 0.2689 - physics_loss: 1.8561
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0835 - loss: 0.2491 - physics_loss: 1.6555
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0845 - loss: 0.2294 - physics_loss: 1.4493
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0854 - loss: 0.2262 - physics_loss: 1.4082
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0869 - loss: 0.2313 - physics_loss: 1.4444
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0860 - loss: 0.2255 - physics_loss: 1.3951
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0823 - loss: 0.2434 - physics_loss: 1.6111
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0845 - loss: 0.2346 - physics_loss: 1.5012
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0853 - loss: 0.1998 - physics_loss: 1.1450
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0837 - loss: 0.1937 - physics_loss: 1.0998
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0842 - loss: 0.1851 - physics_loss: 1.0083
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0864 - loss: 0.1894 - physics_loss: 1.0302
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0875 - loss: 0.2001 - physics_loss: 1.1266
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0820 - loss: 0.2579 - physics_loss: 1.7590
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0863 - loss: 0.2596 - physics_loss: 1.7333
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0835 - loss: 0.2543 - physics_loss: 1.7084
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.0885 - loss: 0.2560 - physics_loss: 1.6752
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.0858 - loss: 0.2493 - physics_loss: 1.6352
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.0818 - loss: 0.2399 - physics_loss: 1.5807
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.0852 - loss: 0.2296 - physics_loss: 1.4440
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.0892 - loss: 0.1701 - physics_loss: 0.8087
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.0914 - loss: 0.1886 - physics_loss: 0.9722
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - data_loss: 0.0847 - loss: 0.2564 - physics_loss: 1.7169
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - data_loss: 0.0860 - loss: 0.2541 - physics_loss: 1.6813
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - data_loss: 0.0856 - loss: 0.2491 - physics_loss: 1.6347
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0862 - loss: 0.2384 - physics_loss: 1.5215
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0887 - loss: 0.2371 - physics_loss: 1.4842
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0869 - loss: 0.1855 - physics_loss: 0.9859
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0941 - loss: 0.2244 - physics_loss: 1.3033
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0873 - loss: 0.2484 - physics_loss: 1.6111
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0835 - loss: 0.2241 - physics_loss: 1.4059
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0884 - loss: 0.1772 - physics_loss: 0.8883
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0883 - loss: 0.1499 - physics_loss: 0.6159
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0878 - loss: 0.1301 - physics_loss: 0.4228
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0829 - loss: 0.1526 - physics_loss: 0.6976
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0826 - loss: 0.1461 - physics_loss: 0.6346
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0969 - loss: 0.2278 - physics_loss: 1.3089
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0942 - loss: 0.1470 - physics_loss: 0.5279
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0842 - loss: 0.2541 - physics_loss: 1.6992
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0844 - loss: 0.2490 - physics_loss: 1.6458
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0854 - loss: 0.2407 - physics_loss: 1.5530
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0876 - loss: 0.2216 - physics_loss: 1.3394
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0890 - loss: 0.1230 - physics_loss: 0.3401
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0969 - loss: 0.1616 - physics_loss: 0.6477
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0892 - loss: 0.2220 - physics_loss: 1.3275
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0865 - loss: 0.1576 - physics_loss: 0.7103
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0925 - loss: 0.1415 - physics_loss: 0.4898
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0869 - loss: 0.1095 - physics_loss: 0.2259
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0920 - loss: 0.1097 - physics_loss: 0.1778
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0918 - loss: 0.1130 - physics_loss: 0.2123
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0984 - loss: 0.1394 - physics_loss: 0.4096
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0866 - loss: 0.2322 - physics_loss: 1.4566
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0859 - loss: 0.1766 - physics_loss: 0.9076
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1041 - loss: 0.1562 - physics_loss: 0.5214
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0830 - loss: 0.1987 - physics_loss: 1.1576
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0901 - loss: 0.1069 - physics_loss: 0.1676
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0964 - loss: 0.1132 - physics_loss: 0.1675
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0871 - loss: 0.1278 - physics_loss: 0.4074
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1010 - loss: 0.1714 - physics_loss: 0.7043
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0854 - loss: 0.1609 - physics_loss: 0.7546
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0973 - loss: 0.1143 - physics_loss: 0.1709
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0893 - loss: 0.1015 - physics_loss: 0.1222
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0901 - loss: 0.1024 - physics_loss: 0.1231
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0873 - loss: 0.0981 - physics_loss: 0.1080
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0879 - loss: 0.0979 - physics_loss: 0.1002
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - data_loss: 0.0879 - loss: 0.0966 - physics_loss: 0.0869
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.0851 - loss: 0.0951 - physics_loss: 0.0999
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0891 - loss: 0.0993 - physics_loss: 0.1017
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0865 - loss: 0.0943 - physics_loss: 0.0782
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0850 - loss: 0.0929 - physics_loss: 0.0794
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.0882 - loss: 0.0955 - physics_loss: 0.0728
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step

# %%
import numpy as np

# ... (Your PINN_AQI_Model class definition and other code) ...

# Assume you have the following pollutant values:
pollutant_values = {
    'T': 25.0,  # Temperature in Celsius
    'P': 1013.25,  # Pressure in hPa
    'H': 60.0,  # Humidity in %
    'SO2': 10.0,  # Sulfur dioxide in ppb
    'NO2': 20.0,  # Nitrogen dioxide in ppb
    'CO': 5.0,  # Carbon monoxide in ppm
    'CO2': 400.0,  # Carbon dioxide in ppm
    'PM2.5': 50.0,  # PM2.5 in µg/m³
    'PM10': 70.0,  # PM10 in µg/m³
    'H2O': 10.0,  # Water vapor in g/m³
    'VOC': 30.0,  # Volatile organic compounds in ppb
    'VOS': 15.0  # Volatile organic sulfur in ppb
}

# Create an input array for the model:
input_data = np.array([[
    pollutant_values['T'],
    pollutant_values['P'],
    pollutant_values['H'],
    pollutant_values['SO2'],
    pollutant_values['NO2'],
    pollutant_values['CO'],
    pollutant_values['CO2'],
    pollutant_values['PM2.5'],
    pollutant_values['PM10'],
    pollutant_values['H2O'],
    pollutant_values['VOC'],
    pollutant_values['VOS']
]])

# Make a prediction using the model:
aqi_prediction = model.predict(input_data)

# To see the output, run the code.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step

# %%
# Print the predicted AQI value:
print("Predicted AQI:", aqi_prediction[0][0])
# Out:
# Predicted AQI: 57.58462

# %%
import numpy as np
# Categorize the AQI prediction
def categorize_aqi(aqi_value):
    if 0 <= aqi_value <= 50:
        return "Good"
    elif 51 <= aqi_value <= 100:
        return "Satisfactory"
    elif 101 <= aqi_value <= 200:
        return "Moderate"
    elif 201 <= aqi_value <= 300:
        return "Poor"
    elif 301 <= aqi_value <= 400:
        return "Very Poor"
    elif 401 <= aqi_value <= 500:
        return "Severe"
    else:
        return "Invalid AQI value"

# Get the AQI category
aqi_category = categorize_aqi(aqi_prediction[0][0])

# Print the predicted AQI value and category
print("Predicted AQI:", aqi_prediction[0][0])
print("AQI Category:", aqi_category)
# Out:
# Predicted AQI: 57.58462
# AQI Category: Satisfactory
